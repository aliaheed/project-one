# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import numpy as np
import requests
import pandas as pd
import openweathermapy.core as owm
from citipy import citipy
from pprint import pprint
import json
import tweepy

from TwitterAPI import TwitterAPI

# %%
api = TwitterAPI('u29AnvDA3vZblxXBibvWRbL01', 'Glmb6Cw8wyeE253AFNCb3QxmjD76kV3rTuJvTF88zjuJZIA11P', '1482319861-T1KxI4qOhe0X1MJq17UqlMriC6ODRE5SasqS4Zf', '1KLIDCB85dfmn8vb8SJrYnsmMqZFMLPc0p406LU0ez1Q2')

# %%
#-122.75,36.8,-121.75,37.8
#r = api.request('statuses/filter', {'locations':'-74,40,-73,41'})
r = api.request('statuses/filter', {'locations':'-122.75,36.8,-121.75,37.8'})  # San FRancisco

#print((r))

for item in r:
        pprint(item)

# %%
# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = '1482319861-T1KxI4qOhe0X1MJq17UqlMriC6ODRE5SasqS4Zf'
ACCESS_TOKEN_SECRET = '1KLIDCB85dfmn8vb8SJrYnsmMqZFMLPc0p406LU0ez1Q2'
CONSUMER_KEY = 'u29AnvDA3vZblxXBibvWRbL01'
CONSUMER_SECRET = 'Glmb6Cw8wyeE253AFNCb3QxmjD76kV3rTuJvTF88zjuJZIA11P'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# Create the api to connect to twitter with your creadentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %%
#print(api)


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
status = api.user_timeline(user='wildfire', count=1)[0]
json.dumps(status)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-e0e2ba7dc570> in <module>
#       6 api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
#       7 status = api.user_timeline(user='wildfire', count=1)[0]
# ----> 8 json.dumps(api.json())
#
# AttributeError: 'API' object has no attribute 'json'

# %%
#---------------------------------------------------------------------------------------------------------------------
# wait_on_rate_limit= True;  will make the api to automatically wait for rate limits to replenish
# wait_on_rate_limit_notify= Ture;  will make the api  to print a notification when Tweepyis waiting for rate limits to replenish
#---------------------------------------------------------------------------------------------------------------------


#---------------------------------------------------------------------------------------------------------------------
# The following loop will print most recent statuses, including retweets, posted by the authenticating user and that user’s friends. 
# This is the equivalent of /timeline/home on the Web.
#---------------------------------------------------------------------------------------------------------------------





for status in tweepy.Cursor(api.home_timeline).items(200):
    pprint(status._json)

    

    


#---------------------------------------------------------------------------------------------------------------------
# Twitter API development use pagination for Iterating through timelines, user lists, direct messages, etc. 
# To help make pagination easier and Tweepy has the Cursor object.
#---------------------------------------------------------------------------------------------------------------------
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:16 +0000 2019',
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/IGLD5b8G1e',
#                          'expanded_url': 'https://twitter.com/ReutersBiz/status/1108144937818865664/photo/1',
#                          'id': 1108144936275398656,
#                          'id_str': '1108144936275398656',
#                          'indices': [105, 128],
#                          'media_url': 'http://pbs.twimg.com/media/D2Dr8sZX0AAWyEg.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D2Dr8sZX0AAWyEg.jpg',
#                          'sizes': {'large': {'h': 682,
#                                              'resize': 'fit',
#                                              'w': 1024},
#                                    'medium': {'h': 682,
#                                               'resize': 'fit',
#                                               'w': 1024},
#                                    'small': {'h': 453,
#                                              'resize': 'fit',
#                                              'w': 680},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/IGLD5b8G1e'}],
#               'symbols': [],
#               'urls': [{'display_url': 'reut.rs/2JqGzQV',
#                         'expanded_url': 'https://reut.rs/2JqGzQV',
#                         'indices': [81, 104],
#                         'url': 'https://t.co/RvxeolQPV0'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/IGLD5b8G1e',
#                                   'expanded_url': 'https://twitter.com/ReutersBiz/status/1108144937818865664/photo/1',
#                                   'id': 1108144936275398656,
#                                   'id_str': '1108144936275398656',
#                                   'indices': [105, 128],
#                                   'media_url': 'http://pbs.twimg.com/media/D2Dr8sZX0AAWyEg.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D2Dr8sZX0AAWyEg.jpg',
#                                   'sizes': {'large': {'h': 682,
#                                                       'resize': 'fit',
#                                                       'w': 1024},
#                                             'medium': {'h': 682,
#                                                        'resize': 'fit',
#                                                        'w': 1024},
#                                             'small': {'h': 453,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/IGLD5b8G1e'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144937818865664,
#  'id_str': '1108144937818865664',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#  'text': 'U.S. bank regulator fines Citigroup $25 million for violating fair '
#          'lending rules https://t.co/RvxeolQPV0 https://t.co/IGLD5b8G1e',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Jun 13 18:56:09 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Top business news around the world. Join us '
#                          '@Reuters, @breakingviews, @ReutersGMF',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'reuters.com/finance',
#                                          'expanded_url': 'http://reuters.com/finance',
#                                          'indices': [0, 22],
#                                          'url': 'http://t.co/PsQMvEFldh'}]}},
#           'favourites_count': 16,
#           'follow_request_sent': False,
#           'followers_count': 2014289,
#           'following': True,
#           'friends_count': 246,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 15110357,
#           'id_str': '15110357',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 22613,
#           'location': 'Around the world',
#           'name': 'Reuters Business',
#           'notifications': False,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15110357/1429124372',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/877263475034042368/xbU9vTKw_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877263475034042368/xbU9vTKw_normal.jpg',
#           'profile_link_color': '009999',
#           'profile_sidebar_border_color': 'EEEEEE',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'ReutersBiz',
#           'statuses_count': 183827,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://t.co/PsQMvEFldh',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:08 +0000 2019',
#  'entities': {'hashtags': [],
#               'media': [{'display_url': 'pic.twitter.com/snt2ZSIfAi',
#                          'expanded_url': 'https://twitter.com/CTVNews/status/1108144907162660864/photo/1',
#                          'id': 1108144905753378816,
#                          'id_str': '1108144905753378816',
#                          'indices': [91, 114],
#                          'media_url': 'http://pbs.twimg.com/media/D2Dr66sWwAAuBya.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D2Dr66sWwAAuBya.jpg',
#                          'sizes': {'large': {'h': 350,
#                                              'resize': 'fit',
#                                              'w': 620},
#                                    'medium': {'h': 350,
#                                               'resize': 'fit',
#                                               'w': 620},
#                                    'small': {'h': 350,
#                                              'resize': 'fit',
#                                              'w': 620},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/snt2ZSIfAi'}],
#               'symbols': [],
#               'urls': [{'display_url': 'bit.ly/2TYMl0a',
#                         'expanded_url': 'http://bit.ly/2TYMl0a',
#                         'indices': [67, 90],
#                         'url': 'https://t.co/vVcsGq9RqP'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/snt2ZSIfAi',
#                                   'expanded_url': 'https://twitter.com/CTVNews/status/1108144907162660864/photo/1',
#                                   'id': 1108144905753378816,
#                                   'id_str': '1108144905753378816',
#                                   'indices': [91, 114],
#                                   'media_url': 'http://pbs.twimg.com/media/D2Dr66sWwAAuBya.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D2Dr66sWwAAuBya.jpg',
#                                   'sizes': {'large': {'h': 350,
#                                                       'resize': 'fit',
#                                                       'w': 620},
#                                             'medium': {'h': 350,
#                                                        'resize': 'fit',
#                                                        'w': 620},
#                                             'small': {'h': 350,
#                                                       'resize': 'fit',
#                                                       'w': 620},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/snt2ZSIfAi'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144907162660864,
#  'id_str': '1108144907162660864',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#  'text': "N.S. woman sheds 100 kg, without joining a gym: 'You need to push' "
#          'https://t.co/vVcsGq9RqP https://t.co/snt2ZSIfAi',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Fri Oct 15 15:48:42 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Tweeting breaking news from CTVNews.ca in the CTV '
#                          'National newsroom. RTs do not constitute endorsement '
#                          'of views.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'ctvnews.ca',
#                                          'expanded_url': 'http://www.ctvnews.ca',
#                                          'indices': [0, 22],
#                                          'url': 'http://t.co/sIkkpnZFhH'}]}},
#           'favourites_count': 25,
#           'follow_request_sent': False,
#           'followers_count': 736587,
#           'following': True,
#           'friends_count': 320,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 203123011,
#           'id_str': '203123011',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 4365,
#           'location': '',
#           'name': 'CTV News',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/203123011/1498059584',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000530407839/22101d60543a76ebf9506a60f37e1534_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000530407839/22101d60543a76ebf9506a60f37e1534_normal.jpeg',
#           'profile_link_color': '0084B4',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'CTVNews',
#           'statuses_count': 157503,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://t.co/sIkkpnZFhH',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:04 +0000 2019',
#  'entities': {'hashtags': [{'indices': [43, 51], 'text': 'Toronto'}],
#               'media': [{'display_url': 'pic.twitter.com/FMD8wV03lt',
#                          'expanded_url': 'https://twitter.com/blogTO/status/1108144888040906753/photo/1',
#                          'id': 1108144886757408768,
#                          'id_str': '1108144886757408768',
#                          'indices': [86, 109],
#                          'media_url': 'http://pbs.twimg.com/media/D2Dr5z7XQAApe6d.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/D2Dr5z7XQAApe6d.jpg',
#                          'sizes': {'large': {'h': 630,
#                                              'resize': 'fit',
#                                              'w': 1200},
#                                    'medium': {'h': 630,
#                                               'resize': 'fit',
#                                               'w': 1200},
#                                    'small': {'h': 357,
#                                              'resize': 'fit',
#                                              'w': 680},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'type': 'photo',
#                          'url': 'https://t.co/FMD8wV03lt'}],
#               'symbols': [],
#               'urls': [{'display_url': 'bit.ly/2TkEwgN',
#                         'expanded_url': 'https://bit.ly/2TkEwgN',
#                         'indices': [62, 85],
#                         'url': 'https://t.co/UQHARqPAfk'}],
#               'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/FMD8wV03lt',
#                                   'expanded_url': 'https://twitter.com/blogTO/status/1108144888040906753/photo/1',
#                                   'id': 1108144886757408768,
#                                   'id_str': '1108144886757408768',
#                                   'indices': [86, 109],
#                                   'media_url': 'http://pbs.twimg.com/media/D2Dr5z7XQAApe6d.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/D2Dr5z7XQAApe6d.jpg',
#                                   'sizes': {'large': {'h': 630,
#                                                       'resize': 'fit',
#                                                       'w': 1200},
#                                             'medium': {'h': 630,
#                                                        'resize': 'fit',
#                                                        'w': 1200},
#                                             'small': {'h': 357,
#                                                       'resize': 'fit',
#                                                       'w': 680},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'type': 'photo',
#                                   'url': 'https://t.co/FMD8wV03lt'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144888040906753,
#  'id_str': '1108144888040906753',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite '
#            'Inc.</a>',
#  'text': 'A rare full worm super moon will rise over #Toronto this week '
#          'https://t.co/UQHARqPAfk https://t.co/FMD8wV03lt',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Mar 15 13:41:17 +0000 2007',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': "Toronto's source for local news and culture, "
#                          'restaurant reviews, event listings and the best of '
#                          'the city. Subscribe to our daily podcast Only in '
#                          'Toronto.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'blogto.com',
#                                          'expanded_url': 'http://www.blogto.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/y5idcAg9KC'}]}},
#           'favourites_count': 11617,
#           'follow_request_sent': False,
#           'followers_count': 639551,
#           'following': True,
#           'friends_count': 11743,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 1223101,
#           'id_str': '1223101',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 5041,
#           'location': 'Toronto',
#           'name': 'blogTO',
#           'notifications': False,
#           'profile_background_color': 'F61600',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1223101/1545444094',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/875520352654417920/JTrAWTPv_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875520352654417920/JTrAWTPv_normal.jpg',
#           'profile_link_color': 'F61600',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'blogTO',
#           'statuses_count': 73397,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/y5idcAg9KC',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:04 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1108144887801749504',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/G2DWK05K1P'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144887801749504,
#  'id_str': '1108144887801749504',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#  'text': 'Opinion: Americans—including Ilhan Omar—should remember those who '
#          'died to give Somalis a chance to live in freedom,… '
#          'https://t.co/G2DWK05K1P',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Apr 01 06:22:13 +0000 2007',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Breaking news and features from the WSJ.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'wsj.com',
#                                          'expanded_url': 'http://wsj.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/GhhR6PLfem'}]}},
#           'favourites_count': 1238,
#           'follow_request_sent': False,
#           'followers_count': 16479831,
#           'following': True,
#           'friends_count': 1125,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 3108351,
#           'id_str': '3108351',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 112011,
#           'location': 'New York, NY',
#           'name': 'The Wall Street Journal',
#           'notifications': False,
#           'profile_background_color': 'EDF2F5',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3108351/1533138007',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/971415515754266624/zCX0q9d5_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971415515754266624/zCX0q9d5_normal.jpg',
#           'profile_link_color': '1164B8',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'WSJ',
#           'statuses_count': 270901,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/GhhR6PLfem',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:01 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'cards.twitter.com/cards/aplb1/72…',
#                         'expanded_url': 'https://cards.twitter.com/cards/aplb1/726ol',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/s7qrah8fSl'}],
#               'user_mentions': [{'id': 718921748,
#                                  'id_str': '718921748',
#                                  'indices': [37, 50],
#                                  'name': 'Bonterra Vineyards',
#                                  'screen_name': 'bonterrawine'},
#                                 {'id': 271986064,
#                                  'id_str': '271986064',
#                                  'indices': [82, 88],
#                                  'name': 'Tesco',
#                                  'screen_name': 'Tesco'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144876300972033,
#  'id_str': '1108144876300972033',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout '
#            'Social</a>',
#  'text': 'Now you can "drink responsibly" with @bonterrawine\'s eco-friendly '
#          "farmed vino and @Tesco's food waste fighting gin. \n"
#          'https://t.co/s7qrah8fSl',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Dec 09 12:37:56 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'The latest news and views from our flourishing world '
#                          'of sustainable business. Join us at #SB19Detroit in '
#                          'June! 🍃',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'sustainablebrands.com',
#                                          'expanded_url': 'http://sustainablebrands.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/I0vnaAvj0j'}]}},
#           'favourites_count': 7817,
#           'follow_request_sent': False,
#           'followers_count': 93279,
#           'following': True,
#           'friends_count': 7979,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 17990173,
#           'id_str': '17990173',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 3324,
#           'location': 'San Francisco, CA',
#           'name': 'Sustainable Brands',
#           'notifications': False,
#           'profile_background_color': 'F3F3F3',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17990173/1545414020',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1076168643006713856/X9rwiyz9_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1076168643006713856/X9rwiyz9_normal.jpg',
#           'profile_link_color': '2BABE2',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': 'EBEBEB',
#           'profile_text_color': '424242',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'SustainBrands',
#           'statuses_count': 128128,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/I0vnaAvj0j',
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:15:01 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'news.cgtn.com/news/3d3d514e3…',
#                         'expanded_url': 'https://news.cgtn.com/news/3d3d514e3159444e33457a6333566d54/index.html',
#                         'indices': [51, 74],
#                         'url': 'https://t.co/o5GrPP5T77'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144874958684160,
#  'id_str': '1108144874958684160',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://about.twitter.com/products/tweetdeck" '
#            'rel="nofollow">TweetDeck</a>',
#  'text': 'Huawei files the most patents as a company in 2018 '
#          'https://t.co/o5GrPP5T77',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jan 24 03:18:59 +0000 2013',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'China Global Television Network, or CGTN, is a '
#                          'multi-language, multi-platform media grouping.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'CGTN.com',
#                                          'expanded_url': 'http://www.CGTN.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/YSOcIymQSt'}]}},
#           'favourites_count': 51,
#           'follow_request_sent': False,
#           'followers_count': 12335225,
#           'following': True,
#           'friends_count': 39,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 1115874631,
#           'id_str': '1115874631',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 6993,
#           'location': 'Beijing, China',
#           'name': 'CGTN',
#           'notifications': False,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1115874631/1483157766',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/969543729500467202/y-kyowAV_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/969543729500467202/y-kyowAV_normal.jpg',
#           'profile_link_color': '009999',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'CGTNOfficial',
#           'statuses_count': 83164,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/YSOcIymQSt',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:14:59 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'bbc.in/2TfCtut',
#                         'expanded_url': 'https://bbc.in/2TfCtut',
#                         'indices': [85, 108],
#                         'url': 'https://t.co/w7fBZgd7pJ'}],
#               'user_mentions': []},
#  'favorite_count': 1,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144869216784386,
#  'id_str': '1108144869216784386',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#  'text': "England's Danny Rose backs Raheem Sterling in criticising portrayal "
#          'of black players https://t.co/w7fBZgd7pJ',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jan 08 08:05:57 +0000 2007',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'News, features and analysis. For world news, follow '
#                          '@BBCWorld. Breaking news, follow @BBCBreaking. '
#                          'Latest sport news @BBCSport. Our Instagram: BBCNews',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'bbc.co.uk/news',
#                                          'expanded_url': 'http://www.bbc.co.uk/news',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/vBzl7LNCCQ'}]}},
#           'favourites_count': 42,
#           'follow_request_sent': False,
#           'followers_count': 9872040,
#           'following': True,
#           'friends_count': 101,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 612473,
#           'id_str': '612473',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 40985,
#           'location': 'London',
#           'name': 'BBC News (UK)',
#           'notifications': False,
#           'profile_background_color': 'FFFFFF',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/612473/1529425670',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/875702547016802304/9TC6qsAT_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875702547016802304/9TC6qsAT_normal.jpg',
#           'profile_link_color': '1F527B',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '5A5A5A',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'BBCNews',
#           'statuses_count': 379249,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/vBzl7LNCCQ',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:14:49 +0000 2019',
#  'entities': {'hashtags': [{'indices': [0, 9], 'text': 'U17Women'},
#                            {'indices': [88, 103], 'text': 'PasiónyOrgullo'}],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1108144825176600576',
#                         'indices': [107, 130],
#                         'url': 'https://t.co/MR2xp2l3fj'}],
#               'user_mentions': [{'id': 310955781,
#                                  'id_str': '310955781',
#                                  'indices': [69, 79],
#                                  'name': 'Maribel D',
#                                  'screen_name': 'MaribelD9'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144825176600576,
#  'id_str': '1108144825176600576',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': "#U17Women | Meet the roster for this week's camp called up by our HC "
#          '@MaribelD9. 🎀⚽🙆🏻\u200d\n'
#          '\n'
#          '#PasiónyOrgullo |… https://t.co/MR2xp2l3fj',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Jun 23 16:49:01 +0000 2015',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Mexican National Teams | For Tweets in Spanish '
#                          'follow @miseleccionmx | #PasiónyOrgullo | #MEXTOUR',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'mextour.org',
#                                          'expanded_url': 'https://www.mextour.org/',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/JQQWtQwXsK'}]}},
#           'favourites_count': 2362,
#           'follow_request_sent': False,
#           'followers_count': 42489,
#           'following': True,
#           'friends_count': 350,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 3253879915,
#           'id_str': '3253879915',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 267,
#           'location': 'México',
#           'name': 'Mexican National Team',
#           'notifications': False,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3253879915/1553007627',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1108020469414821888/w3qPhRGk_normal.png',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1108020469414821888/w3qPhRGk_normal.png',
#           'profile_link_color': '00833E',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'miseleccionmxEN',
#           'statuses_count': 5767,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/JQQWtQwXsK',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:14:36 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1108144771003006976',
#                         'indices': [116, 139],
#                         'url': 'https://t.co/0Jb0zvSjyu'}],
#               'user_mentions': [{'id': 2904233621,
#                                  'id_str': '2904233621',
#                                  'indices': [18, 30],
#                                  'name': 'Babyscripts',
#                                  'screen_name': 'Babyscripts'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144771003006976,
#  'id_str': '1108144771003006976',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite '
#            'Inc.</a>',
#  'text': 'Congratulations‼️ @Babyscripts, a Washington, DC-based virtual care '
#          'platform for managing obstetrics, raised $500K… '
#          'https://t.co/0Jb0zvSjyu',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Mar 16 13:07:08 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': '@StartUpHealth is investing in a global army of '
#                          'Health Transformers to improve the health and '
#                          'wellbeing of everyone in the world.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'startuphealth.com',
#                                          'expanded_url': 'http://www.startuphealth.com',
#                                          'indices': [0, 22],
#                                          'url': 'http://t.co/4kH9kFtGS8'}]}},
#           'favourites_count': 5754,
#           'follow_request_sent': False,
#           'followers_count': 55467,
#           'following': True,
#           'friends_count': 1410,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 267171658,
#           'id_str': '267171658',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 1648,
#           'location': 'New York',
#           'name': 'StartUp Health',
#           'notifications': False,
#           'profile_background_color': '19B69B',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/267171658/1548187800',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/720989189618167808/xlBYQx7p_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720989189618167808/xlBYQx7p_normal.jpg',
#           'profile_link_color': '079BC6',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'startuphealth',
#           'statuses_count': 15391,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://t.co/4kH9kFtGS8',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:14:17 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1108144690531131394',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/f8HKtbtpYg'}],
#               'user_mentions': []},
#  'favorite_count': 5,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144690531131394,
#  'id_str': '1108144690531131394',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'retweet_count': 2,
#  'retweeted': False,
#  'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#  'text': 'Brexanolone is not a pill. The drug is delivered intravenously over '
#          'the course of a 60-hour infusion, meaning it mu… '
#          'https://t.co/f8HKtbtpYg',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Tue Mar 18 23:19:17 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'The leading source of global news and info for more '
#                          'than 75 years. https://t.co/Hd7rJQeDzP',
#           'entities': {'description': {'urls': [{'display_url': 'instagram.com/nbcnews',
#                                                  'expanded_url': 'https://www.instagram.com/nbcnews',
#                                                  'indices': [67, 90],
#                                                  'url': 'https://t.co/Hd7rJQeDzP'}]},
#                        'url': {'urls': [{'display_url': 'NBCNews.com',
#                                          'expanded_url': 'http://NBCNews.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/Z73is4fJ3x'}]}},
#           'favourites_count': 768,
#           'follow_request_sent': False,
#           'followers_count': 6451135,
#           'following': True,
#           'friends_count': 1761,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 14173315,
#           'id_str': '14173315',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 41083,
#           'location': 'New York, NY',
#           'name': 'NBC News',
#           'notifications': False,
#           'profile_background_color': '062131',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14173315/1552566771',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg',
#           'profile_link_color': '5172A0',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'FFFFFF',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'NBCNews',
#           'statuses_count': 197769,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/Z73is4fJ3x',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 23:14:09 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 892275857779118080,
#                                  'id_str': '892275857779118080',
#                                  'indices': [7, 16],
#                                  'name': 'Devin Nunes’ cow',
#                                  'screen_name': 'DevinCow'}]},
#  'favorite_count': 61,
#  'favorited': False,
#  'geo': None,
#  'id': 1108144658574700544,
#  'id_str': '1108144658574700544',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 10,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'Follow @DevinCow. Because the satire is a rare medium well-done.',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jan 13 19:33:56 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Some know me as Mr. Sulu from Star Trek but I hope '
#                          'all know me as a believer in, and a fighter for, the '
#                          'equality and dignity of all human beings.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'shop.spreadshirt.com/takei-tees',
#                                          'expanded_url': 'https://shop.spreadshirt.com/takei-tees',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/MXbB9zIvs9'}]}},
#           'favourites_count': 3227,
#           'follow_request_sent': False,
#           'followers_count': 2852181,
#           'following': True,
#           'friends_count': 741,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 237845487,
#           'id_str': '237845487',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 23032,
#           'location': 'Broadway - New York, NY',
#           'name': 'George Takei',
#           'notifications': False,
#           'profile_background_color': '022330',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
# ...
#                       'id_str': '1108137217359257600',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'possibly_sensitive_appealable': False,
#                       'retweet_count': 14,
#                       'retweeted': False,
#                       'source': '<a href="http://www.snapstream.com" '
#                                 'rel="nofollow">SnapStream TV Search</a>',
#                       'text': 'U.S.-backed forces in Syria seized control of '
#                               'the last ISIS-held territory Tuesday - a '
#                               'significant step toward defe… '
#                               'https://t.co/d6yJRRbJge',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Wed May 27 20:08:03 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'The official account of The CBS '
#                                               'Evening News with @JeffGlor, '
#                                               'the longest running evening '
#                                               'newscast.',
#                                'entities': {'description': {'urls': []},
#                                             'url': {'urls': [{'display_url': 'CBSEveningNews.com',
#                                                               'expanded_url': 'http://CBSEveningNews.com',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/Mm7FlsMteV'}]}},
#                                'favourites_count': 1142,
#                                'follow_request_sent': False,
#                                'followers_count': 301948,
#                                'following': False,
#                                'friends_count': 1551,
#                                'geo_enabled': True,
#                                'has_extended_profile': False,
#                                'id': 42958829,
#                                'id_str': '42958829',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 4169,
#                                'location': '📺 6:30pm ET',
#                                'name': 'CBS Evening News',
#                                'notifications': False,
#                                'profile_background_color': 'FFFFFF',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42958829/1536904846',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/938483676668682241/yD0g0Li__normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/938483676668682241/yD0g0Li__normal.jpg',
#                                'profile_link_color': '2C537C',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'DDDEE4',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'CBSEveningNews',
#                                'statuses_count': 93732,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://t.co/Mm7FlsMteV',
#                                'utc_offset': None,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'RT @CBSEveningNews: U.S.-backed forces in Syria seized control of '
#          'the last ISIS-held territory Tuesday - a significant step toward '
#          'defeatin…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Your source for original reporting and trusted news.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'CBSNews.com',
#                                          'expanded_url': 'http://CBSNews.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/VGut7r2Vg5'}]}},
#           'favourites_count': 285,
#           'follow_request_sent': False,
#           'followers_count': 6663690,
#           'following': True,
#           'friends_count': 437,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 15012486,
#           'id_str': '15012486',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 49798,
#           'location': 'New York, NY',
#           'name': 'CBS News',
#           'notifications': False,
#           'profile_background_color': 'D9DADA',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1527023725',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#           'profile_link_color': 'B12124',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EAEDF0',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'CBSNews',
#           'statuses_count': 207512,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/VGut7r2Vg5',
#           'utc_offset': None,
#           'verified': True}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Mar 19 22:47:48 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 42958829,
#                                  'id_str': '42958829',
#                                  'indices': [3, 18],
#                                  'name': 'CBS Evening News',
#                                  'screen_name': 'CBSEveningNews'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1108138025295458304,
#  'id_str': '1108138025295458304',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 13,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Tue Mar 19 22:42:12 +0000 2019',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/1108136619620605952',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/L5MjGqf2dT'}],
#                                    'user_mentions': []},
#                       'favorite_count': 14,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 1108136619620605952,
#                       'id_str': '1108136619620605952',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'possibly_sensitive_appealable': False,
#                       'retweet_count': 13,
#                       'retweeted': False,
#                       'source': '<a href="http://www.snapstream.com" '
#                                 'rel="nofollow">SnapStream TV Search</a>',
#                       'text': 'The FAA approval process for Boeing 737 Max '
#                               'airplanes will be reviewed after two fatal '
#                               'crashes -- one congressman w… '
#                               'https://t.co/L5MjGqf2dT',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Wed May 27 20:08:03 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'The official account of The CBS '
#                                               'Evening News with @JeffGlor, '
#                                               'the longest running evening '
#                                               'newscast.',
#                                'entities': {'description': {'urls': []},
#                                             'url': {'urls': [{'display_url': 'CBSEveningNews.com',
#                                                               'expanded_url': 'http://CBSEveningNews.com',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/Mm7FlsMteV'}]}},
#                                'favourites_count': 1142,
#                                'follow_request_sent': False,
#                                'followers_count': 301948,
#                                'following': False,
#                                'friends_count': 1551,
#                                'geo_enabled': True,
#                                'has_extended_profile': False,
#                                'id': 42958829,
#                                'id_str': '42958829',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 4169,
#                                'location': '📺 6:30pm ET',
#                                'name': 'CBS Evening News',
#                                'notifications': False,
#                                'profile_background_color': 'FFFFFF',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42958829/1536904846',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/938483676668682241/yD0g0Li__normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/938483676668682241/yD0g0Li__normal.jpg',
#                                'profile_link_color': '2C537C',
#                                'profile_sidebar_border_color': 'FFFFFF',
#                                'profile_sidebar_fill_color': 'DDDEE4',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'CBSEveningNews',
#                                'statuses_count': 93732,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://t.co/Mm7FlsMteV',
#                                'utc_offset': None,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': 'RT @CBSEveningNews: The FAA approval process for Boeing 737 Max '
#          'airplanes will be reviewed after two fatal crashes -- one '
#          'congressman worri…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Your source for original reporting and trusted news.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'CBSNews.com',
#                                          'expanded_url': 'http://CBSNews.com',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/VGut7r2Vg5'}]}},
#           'favourites_count': 285,
#           'follow_request_sent': False,
#           'followers_count': 6663690,
#           'following': True,
#           'friends_count': 437,
#           'geo_enabled': False,
#           'has_extended_profile': False,
#           'id': 15012486,
#           'id_str': '15012486',
#           'is_translation_enabled': True,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 49798,
#           'location': 'New York, NY',
#           'name': 'CBS News',
#           'notifications': False,
#           'profile_background_color': 'D9DADA',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1527023725',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#           'profile_link_color': 'B12124',
#           'profile_sidebar_border_color': 'FFFFFF',
#           'profile_sidebar_fill_color': 'EAEDF0',
#           'profile_text_color': '000000',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'CBSNews',
#           'statuses_count': 207512,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/VGut7r2Vg5',
#           'utc_offset': None,
#           'verified': True}}

# %%
#---------------------------------------------------------------------------------------------------------------------
# wait_on_rate_limit= True;  will make the api to automatically wait for rate limits to replenish
# wait_on_rate_limit_notify= Ture;  will make the api  to print a notification when Tweepyis waiting for rate limits to replenish
#---------------------------------------------------------------------------------------------------------------------


#---------------------------------------------------------------------------------------------------------------------
# The following loop will print most recent statuses, including retweets, posted by the authenticating user and that user’s friends. 
# This is the equivalent of /timeline/home on the Web.
#---------------------------------------------------------------------------------------------------------------------

print (type(api))






#---------------------------------------------------------------------------------------------------------------------
# Twitter API development use pagination for Iterating through timelines, user lists, direct messages, etc. 
# To help make pagination easier and Tweepy has the Cursor object.
#---------------------------------------------------------------------------------------------------------------------
# Out:
# <class 'tweepy.api.API'>

# %%
ll_class = []

class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        #ll_class.append(status.text)
        
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["wildfire"],languages=["en"])

# %%
class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["rainfall"],languages=["en"])
