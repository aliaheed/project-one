# %%
# Dependencies
# %matplotlib inline

import csv
import matplotlib.pyplot as plt
import numpy as np
import requests
import pandas as pd
import openweathermapy.core as owm
from citipy import citipy
from pprint import pprint
import json
import plotly

import tweepy

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ae57816b47a1> in <module>
#      13 import plotly
#      14
# ---> 15 import tweepy
#      16
#      17 import plotly
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
lnd_temp = 'Resources/GlobalLandTemperaturesByState.csv'
wildfire = 'Resources/US_Fires_Over_One_Acre.csv'

lnd_temp_df = pd.read_csv(lnd_temp, low_memory=False)
wildfire_df = pd.read_csv(wildfire, low_memory=False)


lnd_temp_df.head()
#wildfire_df.head()

# %%
temp_us_df = lnd_temp_df[lnd_temp_df['Country']=='United States']

# %%
temp_us_df.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty    State  \
# 7458  1743-11-01              10.722                          2.898  Alabama
# 7459  1743-12-01                 NaN                            NaN  Alabama
# 7460  1744-01-01                 NaN                            NaN  Alabama
# 7461  1744-02-01                 NaN                            NaN  Alabama
# 7462  1744-03-01                 NaN                            NaN  Alabama
#
#             Country
# 7458  United States
# 7459  United States
# 7460  United States
# 7461  United States
# 7462  United States

# %%
temp_us_df['year'] = temp_us_df.dt.str.extract(r'([0-9][0-9][0-9][0-9])', expand=True)
# Out:
# C:\Users\aliqu\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
temp_us_df.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty    State  \
# 7458  1743-11-01              10.722                          2.898  Alabama
# 7459  1743-12-01                 NaN                            NaN  Alabama
# 7460  1744-01-01                 NaN                            NaN  Alabama
# 7461  1744-02-01                 NaN                            NaN  Alabama
# 7462  1744-03-01                 NaN                            NaN  Alabama
#
#             Country  year
# 7458  United States  1743
# 7459  United States  1743
# 7460  United States  1744
# 7461  United States  1744
# 7462  United States  1744

# %%
# drop columns with NaN

temp_us_df = temp_us_df.dropna(subset = ['AverageTemperature', 'AverageTemperatureUncertainty'])
temp_us_df.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty    State  \
# 7458  1743-11-01              10.722                          2.898  Alabama
# 7463  1744-04-01              19.075                          2.902  Alabama
# 7464  1744-05-01              21.197                          2.844  Alabama
# 7465  1744-06-01              25.290                          2.879  Alabama
# 7466  1744-07-01              26.420                          2.841  Alabama
#
#             Country  year
# 7458  United States  1743
# 7463  United States  1744
# 7464  United States  1744
# 7465  United States  1744
# 7466  United States  1744

# %%
#1992 - 2015

temp_us_df = temp_us_df[(temp_us_df['year'] >= '1992') & (temp_us_df['year'] <= '2015')]
temp_us_df.head()
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    State  \
# 10436  1992-01-01               6.979                          0.218  Alabama
# 10437  1992-02-01              10.898                          0.243  Alabama
# 10438  1992-03-01              12.995                          0.197  Alabama
# 10439  1992-04-01              16.589                          0.297  Alabama
# 10440  1992-05-01              20.430                          0.139  Alabama
#
#              Country  year
# 10436  United States  1992
# 10437  United States  1992
# 10438  United States  1992
# 10439  United States  1992
# 10440  United States  1992

# %%
temp_us_df.year.unique()
# Out:
# array(['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013'], dtype=object)

# %%
temp_us_group_df = temp_us_df.groupby(['year', 'State'])["AverageTemperature"].sum()/temp_us_df.groupby(['year', 'State'])["AverageTemperature"].count()

temp_us_group_df = temp_us_group_df.to_frame().reset_index()
#temp_us_group_df.head()


temp_us_group_df.year.unique()

#temp_us_df.groupby(['year', 'State'])["AverageTemperature"].count()
#temp_us_df.groupby(['year', 'State']).count()

#temp_us_df.groupby(['year', 'State'])["AverageTemperature"].sum()
#t_df=temp_us_df.groupby(['year', 'State'])["AverageTemperature"].sum()
#export_csv = t_df.to_csv (r'Resources\Temperature_US_df.csv', index = None, header=True)
# Out:
# array(['1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013'], dtype=object)

# %%
#t_df = temp_us_df.groupby(['year', 'State']).nunique()
#t_df.head()
#export_csv = t_df.to_csv (r'Resources\Temperature_US_df.csv', index = None, header=True)

# %%
#temp_us_group_df = temp_us_group_df.to_frame().reset_index()

# %%
temp_us_group_df.head()
# Out:
#    year       State  AverageTemperature
# 0  1992     Alabama           17.038583
# 1  1992      Alaska           -5.104333
# 2  1992     Arizona           15.429083
# 3  1992    Arkansas           15.797667
# 4  1992  California           15.276917

# %%
# Removing Puerto Rico

#temp_us_group_df = temp_us_group_df[temp_us_group_df['State']!='Puerto Rico'].head()

# %%
### only 1992 and 4 or 5 states are left by this time

#temp_us_group_df.head()

temp_us_group_df.State.unique()
#temp_us_group_df.year.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
#        'Florida', 'Georgia (State)', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# T(°F) = T(°C) × 1.8 + 32


temp_us_group_df['AverageTemperature_F'] = temp_us_group_df.AverageTemperature * 1.8 + 32

# %%
temp_us_group_df = temp_us_group_df.rename(columns={"State":"state_name"})
temp_us_group_df.head()

#temp_us_group_df.state_name.unique()
#temp_us_group_df.year.unique()
# Out:
#    year  state_name  AverageTemperature  AverageTemperature_F
# 0  1992     Alabama           17.038583              62.66945
# 1  1992      Alaska           -5.104333              22.81220
# 2  1992     Arizona           15.429083              59.77235
# 3  1992    Arkansas           15.797667              60.43580
# 4  1992  California           15.276917              59.49845

# %%
wildfire_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  FOD_ID FIRE_NAME  FIRE_YEAR  DISCOVERY_DATE  \
# 0           0            13      14     TIGER       2004       2453276.5
# 1           1            16      17     POWER       2004       2453284.5
# 2           2            17      18     FREDS       2004       2453291.5
# 3           3            24      25     EAGLE       2004       2453187.5
# 4           4            25      26  BACHELOR       2004       2453206.5
#
#    DISCOVERY_DOY  DISCOVERY_TIME  STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE  \
# 0            272          1200.0              4.0         Campfire        6.0
# 1            280          1415.0              2.0    Equipment Use    16823.0
# 2            287          1618.0              2.0    Equipment Use     7700.0
# 3            183          1712.0              1.0        Lightning        2.5
# 4            202          1405.0              1.0        Lightning       10.0
#
#   FIRE_SIZE_CLASS   LATITUDE   LONGITUDE STATE COUNTY
# 0               B  38.433333 -120.510000    CA      5
# 1               G  38.523333 -120.211667    CA      5
# 2               G  38.780000 -120.260000    CA     17
# 3               B  33.545278 -105.229444    NM     27
# 4               C  33.315833 -105.512222    NM     27

# %%
wildfire_df = wildfire_df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
wildfire_df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 0      14     TIGER       2004       2453276.5            272          1200.0
# 1      17     POWER       2004       2453284.5            280          1415.0
# 2      18     FREDS       2004       2453291.5            287          1618.0
# 3      25     EAGLE       2004       2453187.5            183          1712.0
# 4      26  BACHELOR       2004       2453206.5            202          1405.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0              4.0         Campfire        6.0               B  38.433333
# 1              2.0    Equipment Use    16823.0               G  38.523333
# 2              2.0    Equipment Use     7700.0               G  38.780000
# 3              1.0        Lightning        2.5               B  33.545278
# 4              1.0        Lightning       10.0               C  33.315833
#
#     LONGITUDE STATE COUNTY
# 0 -120.510000    CA      5
# 1 -120.211667    CA      5
# 2 -120.260000    CA     17
# 3 -105.229444    NM     27
# 4 -105.512222    NM     27

# %%
wildfire_df = wildfire_df.rename(columns={"STATE":"state_abb","FIRE_YEAR":"year"})
wildfire_df.head()
# Out:
#    FOD_ID FIRE_NAME  year  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 0      14     TIGER  2004       2453276.5            272          1200.0
# 1      17     POWER  2004       2453284.5            280          1415.0
# 2      18     FREDS  2004       2453291.5            287          1618.0
# 3      25     EAGLE  2004       2453187.5            183          1712.0
# 4      26  BACHELOR  2004       2453206.5            202          1405.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0              4.0         Campfire        6.0               B  38.433333
# 1              2.0    Equipment Use    16823.0               G  38.523333
# 2              2.0    Equipment Use     7700.0               G  38.780000
# 3              1.0        Lightning        2.5               B  33.545278
# 4              1.0        Lightning       10.0               C  33.315833
#
#     LONGITUDE state_abb COUNTY
# 0 -120.510000        CA      5
# 1 -120.211667        CA      5
# 2 -120.260000        CA     17
# 3 -105.229444        NM     27
# 4 -105.512222        NM     27

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
# converting list to a pandas dataframe

list_key_value = [ [k,v] for k, v in states.items() ]

states_df = pd.DataFrame(np.array(list_key_value).reshape(-1,2), columns = list("ab"))

states_df = states_df.rename(columns={"a":"state_abb", "b":"state_name"})
states_df.head()
# Out:
#   state_abb      state_name
# 0        AK          Alaska
# 1        AL         Alabama
# 2        AR        Arkansas
# 3        AS  American Samoa
# 4        AZ         Arizona

# %%
wildfire_states_df = pd.merge(wildfire_df,states_df, on="state_abb" )
wildfire_states_df.head()
# Out:
#    FOD_ID FIRE_NAME  year  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 0      14     TIGER  2004       2453276.5            272          1200.0
# 1      17     POWER  2004       2453284.5            280          1415.0
# 2      18     FREDS  2004       2453291.5            287          1618.0
# 3     111    SADDLE  2005       2453540.5            170          1500.0
# 4     158    APACHE  2005       2453411.5             41          1337.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0              4.0         Campfire        6.0               B  38.433333
# 1              2.0    Equipment Use    16823.0               G  38.523333
# 2              2.0    Equipment Use     7700.0               G  38.780000
# 3              2.0    Equipment Use       10.0               C  33.718889
# 4              5.0   Debris Burning        3.0               B  34.748333
#
#     LONGITUDE state_abb COUNTY  state_name
# 0 -120.510000        CA      5  California
# 1 -120.211667        CA      5  California
# 2 -120.260000        CA     17  California
# 3 -117.433611        CA    NaN  California
# 4 -119.410278        CA    NaN  California

# %%
wildfire_states_df['year']=wildfire_states_df['year'].astype(int)
temp_us_group_df['year']=temp_us_group_df['year'].astype(int)

wildfire_temperature_df = pd.merge(wildfire_states_df, temp_us_group_df,   on=['year','state_name'], how='inner')

wildfire_temperature_df.head()
# Out:
#    FOD_ID FIRE_NAME  year  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 0      14     TIGER  2004       2453276.5            272          1200.0
# 1      17     POWER  2004       2453284.5            280          1415.0
# 2      18     FREDS  2004       2453291.5            287          1618.0
# 3  165954     ENGEL  2004       2453082.5             78          1414.0
# 4  166325     SHINE  2004       2453111.5            107          1543.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0              4.0         Campfire        6.0               B  38.433333
# 1              2.0    Equipment Use    16823.0               G  38.523333
# 2              2.0    Equipment Use     7700.0               G  38.780000
# 3              5.0   Debris Burning        2.5               B  40.175278
# 4              5.0   Debris Burning        4.0               B  39.400278
#
#     LONGITUDE state_abb COUNTY  state_name  AverageTemperature  \
# 0 -120.510000        CA      5  California            15.06875
# 1 -120.211667        CA      5  California            15.06875
# 2 -120.260000        CA     17  California            15.06875
# 3 -120.785556        CA    NaN  California            15.06875
# 4 -121.103611        CA    NaN  California            15.06875
#
#    AverageTemperature_F
# 0              59.12375
# 1              59.12375
# 2              59.12375
# 3              59.12375
# 4              59.12375

# %%
export_csv = wildfire_temperature_df.to_csv (r'Resources\export_dataframe.csv', index = None, header=True)

# %%
#wildfire_temperature_df.state_name.unique()
wildfire_states_df.year.unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2010, 2011, 2012, 2013,
#        2014, 2015], dtype=int64)

# %%
temp_us_group_df.state_name.unique()
#temp_us_group_df.year.unique()
#temp_us_group_df.head()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
#        'Florida', 'Georgia (State)', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
export_csv = temp_us_group_df.to_csv (r'Resources\Temperature_US_df.csv', index = None, header=True)

# %%
#temp_us_group_df.head()

wildfire_temperature_df.head()
# Out:
#    FOD_ID FIRE_NAME  year  DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 0      14     TIGER  2004       2453276.5            272          1200.0
# 1      17     POWER  2004       2453284.5            280          1415.0
# 2      18     FREDS  2004       2453291.5            287          1618.0
# 3  165954     ENGEL  2004       2453082.5             78          1414.0
# 4  166325     SHINE  2004       2453111.5            107          1543.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0              4.0         Campfire        6.0               B  38.433333
# 1              2.0    Equipment Use    16823.0               G  38.523333
# 2              2.0    Equipment Use     7700.0               G  38.780000
# 3              5.0   Debris Burning        2.5               B  40.175278
# 4              5.0   Debris Burning        4.0               B  39.400278
#
#     LONGITUDE state_abb COUNTY  state_name  AverageTemperature  \
# 0 -120.510000        CA      5  California            15.06875
# 1 -120.211667        CA      5  California            15.06875
# 2 -120.260000        CA     17  California            15.06875
# 3 -120.785556        CA    NaN  California            15.06875
# 4 -121.103611        CA    NaN  California            15.06875
#
#    AverageTemperature_F
# 0              59.12375
# 1              59.12375
# 2              59.12375
# 3              59.12375
# 4              59.12375

# %%
export_csv = wildfire_temperature_df.to_csv (r'Resources\Temperature_US_df.csv', index = None, header=True)

# %%
wildfire_temperature_df.state_name.unique()
#wildfire_states_df.year.unique()
# Out:
# array(['California', 'New Mexico', 'North Carolina', 'Oregon', 'Montana',
#        'Nevada', 'Colorado', 'South Dakota', 'Arizona', 'Minnesota',
#        'Texas', 'Arkansas', 'South Carolina', 'Louisiana', 'Oklahoma',
#        'Wyoming', 'Utah', 'Florida', 'Missouri', 'Kansas', 'Idaho',
#        'Nebraska', 'Washington', 'Michigan', 'Kentucky', 'Ohio',
#        'Indiana', 'Virginia', 'Illinois', 'Tennessee', 'North Dakota',
#        'West Virginia', 'Wisconsin', 'Pennsylvania', 'Alabama',
#        'Mississippi', 'New Hampshire', 'Maine', 'Vermont', 'New York',
#        'Iowa', 'Maryland', 'Connecticut', 'Massachusetts', 'New Jersey',
#        'Delaware', 'Rhode Island'], dtype=object)

# %%
wildfire_temperature_few_cols_df = wildfire_temperature_df[['year', 'state_abb','state_name','FIRE_SIZE','AverageTemperature_F']]
wildfire_temperature_few_cols_df.head()
#wildfire_temperature_few_cols_df.count()
# Out:
#    year state_abb  state_name  FIRE_SIZE  AverageTemperature_F
# 0  2004        CA  California        6.0              59.12375
# 1  2004        CA  California    16823.0              59.12375
# 2  2004        CA  California     7700.0              59.12375
# 3  2004        CA  California        2.5              59.12375
# 4  2004        CA  California        4.0              59.12375

# %%
wildfire_temperature_fewcol_group_df = wildfire_temperature_few_cols_df.groupby(['year', 'state_abb','state_name'])["FIRE_SIZE","AverageTemperature_F"].sum()
wildfire_temperature_fewcol_group_df.head()

#df.sort_values(by='col1', ascending=False, na_position='first')

#wildfire_temperature_sort_df = df.sort_values(by='col1', ascending=False, na_position='first')
# Out:
#                            FIRE_SIZE  AverageTemperature_F
# year state_abb state_name
# 1992 AL        Alabama        1238.0            3634.82810
#      AR        Arkansas       1468.0            5378.78620
#      AZ        Arizona       41916.2           55946.91960
#      CA        California   294114.9          136786.93655
#      CO        Colorado       7248.7            8437.56155

# %%
wildfire_temperature_fewcol_group_df = wildfire_temperature_fewcol_group_df.reset_index()
wildfire_temperature_fewcol_group_df.head()
# Out:
#    year state_abb  state_name  FIRE_SIZE  AverageTemperature_F
# 0  1992        AL     Alabama     1238.0            3634.82810
# 1  1992        AR    Arkansas     1468.0            5378.78620
# 2  1992        AZ     Arizona    41916.2           55946.91960
# 3  1992        CA  California   294114.9          136786.93655
# 4  1992        CO    Colorado     7248.7            8437.56155

# %%
#wildfire_temperature_fewcol_group_df = wildfire_temperature_fewcol_group_df.drop(['level_0', 'index'], axis=1)
wildfire_temperature_fewcol_group_df.head()


#df=wildfire_temperature_fewcol_group_df.groupby('year','state_abb','state_name').agg({'FIRE_SIZE':'sum', 'AverageTemperature_F':'mean'})   #.rename(columns=d)
#df



#df.head()
#df['total_fire_size']=wildfire_temperature_few_cols_df.loc[:,FIRE_SIZE].sum(axis=1)
# Out:
#    year state_abb  state_name  FIRE_SIZE  AverageTemperature_F
# 0  1992        AL     Alabama     1238.0            3634.82810
# 1  1992        AR    Arkansas     1468.0            5378.78620
# 2  1992        AZ     Arizona    41916.2           55946.91960
# 3  1992        CA  California   294114.9          136786.93655
# 4  1992        CO    Colorado     7248.7            8437.56155

# %%
df_firesize = wildfire_temperature_few_cols_df.groupby(['year', 'state_abb','state_name'])["FIRE_SIZE"].count()
df_firesize.head()
# Out:
# year  state_abb  state_name
# 1992  AL         Alabama         58
#       AR         Arkansas        89
#       AZ         Arizona        936
#       CA         California    2299
#       CO         Colorado       187
# Name: FIRE_SIZE, dtype: int64

# %%
df_firesize = df_firesize.to_frame().reset_index()
df_firesize.head()
# Out:
#    year state_abb  state_name  FIRE_SIZE
# 0  1992        AL     Alabama         58
# 1  1992        AR    Arkansas         89
# 2  1992        AZ     Arizona        936
# 3  1992        CA  California       2299
# 4  1992        CO    Colorado        187

# %%
df_firesize.count()
# Out:
# year          999
# state_abb     999
# state_name    999
# FIRE_SIZE     999
# dtype: int64

# %%
df_AverageTemp_F = wildfire_temperature_few_cols_df.groupby(['year', 'state_abb','state_name'])["AverageTemperature_F"].mean()
df_AverageTemp_F.head()
# Out:
# year  state_abb  state_name
# 1992  AL         Alabama       62.66945
#       AR         Arkansas      60.43580
#       AZ         Arizona       59.77235
#       CA         California    59.49845
#       CO         Colorado      45.12065
# Name: AverageTemperature_F, dtype: float64

# %%
df_AverageTemp_F = df_AverageTemp_F.to_frame().reset_index()
df_AverageTemp_F.head()
# Out:
#    year state_abb  state_name  AverageTemperature_F
# 0  1992        AL     Alabama              62.66945
# 1  1992        AR    Arkansas              60.43580
# 2  1992        AZ     Arizona              59.77235
# 3  1992        CA  California              59.49845
# 4  1992        CO    Colorado              45.12065

# %%
final_df = pd.merge(df_firesize, df_AverageTemp_F,   on=['year','state_abb','state_name'], how='inner')

# %%
final_df.head()
# Out:
#    year state_abb  state_name  FIRE_SIZE  AverageTemperature_F
# 0  1992        AL     Alabama         58              62.66945
# 1  1992        AR    Arkansas         89              60.43580
# 2  1992        AZ     Arizona        936              59.77235
# 3  1992        CA  California       2299              59.49845
# 4  1992        CO    Colorado        187              45.12065

# %%
final_df.count()
# Out:
# year                    999
# state_abb               999
# state_name              999
# FIRE_SIZE               999
# AverageTemperature_F    999
# dtype: int64

# %%
final_sort_count_df = final_df.sort_values(by='FIRE_SIZE', ascending=False, na_position='first')

# %%
final_sort_count_df.head()
# Out:
#      year state_abb state_name  FIRE_SIZE  AverageTemperature_F
# 766  2008        TX      Texas       9685              65.68160
# 674  2006        TX      Texas       9230              67.26125
# 900  2011        TX      Texas       9211              67.49255
# 811  2009        TX      Texas       6664              65.89865
# 628  2005        TX      Texas       4476              66.11825

# %%
df_year_AverageTemp_F = wildfire_temperature_few_cols_df.groupby(['year'])["AverageTemperature_F"].mean()
#df_year_AverageTemp_F.head()

df_year_AverageTemp_F = df_year_AverageTemp_F.to_frame().reset_index()
df_year_AverageTemp_F.head()
# Out:
#    year  AverageTemperature_F
# 0  1992             58.527988
# 1  1993             59.291739
# 2  1994             57.602551
# 3  1995             58.850978
# 4  1996             58.790539

# %%
df_year_count_state = wildfire_temperature_few_cols_df.groupby(['year'])["FIRE_SIZE"].count()
#df_year_count_state.head()

df_year_count_state = df_year_count_state.to_frame().reset_index()
df_year_count_state.head()
# Out:
#    year  FIRE_SIZE
# 0  1992      22964
# 1  1993      21381
# 2  1994      26557
# 3  1995      26530
# 4  1996      28267

# %%
year_count_avg_df = pd.merge(df_year_count_state, df_year_AverageTemp_F,   on=['year'], how='inner')
year_count_avg_df.head()
# Out:
#    year  FIRE_SIZE  AverageTemperature_F
# 0  1992      22964             58.527988
# 1  1993      21381             59.291739
# 2  1994      26557             57.602551
# 3  1995      26530             58.850978
# 4  1996      28267             58.790539

# %%
year_sort_count_avg_df = year_count_avg_df.sort_values(by='year', ascending=True, na_position='first')
year_sort_count_avg_df.head()
# Out:
#    year  FIRE_SIZE  AverageTemperature_F
# 0  1992      22964             58.527988
# 1  1993      21381             59.291739
# 2  1994      26557             57.602551
# 3  1995      26530             58.850978
# 4  1996      28267             58.790539

# %%
List_year = []
List_fire_count = []
List_temp_avg_f = []



List_year = list(year_sort_count_avg_df['year'])
List_fire_count = list(year_sort_count_avg_df['FIRE_SIZE'])
List_temp_avg_f = list(year_sort_count_avg_df['AverageTemperature_F']) 


fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle("Fire Size and Avg Temp in (F)", fontsize=16, fontweight="bold")


x_axis = np.arange(len(List_year))

ax1.plot(List_year, List_fire_count, linewidth=1, marker="o")
ax1.set_ylabel("Fire Count")

ax2.plot(List_year, List_temp_avg_f, linewidth=1, marker="o")
ax2.set_ylabel("avg temp")


#plt.bar(x_axis, List_fire_count, color="b", align="center")


tick_locations = [value for value in x_axis]

# %%
state_temp_mean_df = final_df.groupby(['state_name','state_abb'])["AverageTemperature_F"].mean()

state_temp_mean_df = state_temp_mean_df.to_frame().reset_index()
state_temp_mean_df.head()
# Out:
#    state_name state_abb  AverageTemperature_F
# 0     Alabama        AL             64.120909
# 1     Arizona        AZ             61.108145
# 2    Arkansas        AR             61.567573
# 3  California        CA             59.000180
# 4    Colorado        CO             46.022077

# %%
export_csv = state_temp_mean_df.to_csv (r'Resources\plotly_df.csv', index = None, header=True)

# %%
# Now to make cloropleth map using the plotly library and API

for col in state_temp_mean_df.columns:
    state_temp_mean_df[col] = state_temp_mean_df[col].astype(str)

# Select the colors for the gradient     
scl = [[0.0, 'rgb(255,215,0)'],
       [0.2, 'rgb(255,165,0)'],
       [0.4, 'rgb(255,140,0)'],
       [0.6, 'rgb(255,115,0)'],
       [0.8, 'rgb(200,50,0)'],
       [1.0, 'rgb(139,0,0)']]

#Load the dictionary for a choropleth map 
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = state_temp_mean_df['state_name'],
        z = state_temp_mean_df["AverageTemperature_F"],
        locationmode = 'USA-states',
        text = state_temp_mean_df['state_abb'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Average Temperatures")
        ) ]

# Add title and labels 
layout = dict(
        title = 'USA Rainfall 1992-2013 </br></br>Source: Kaggle',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )

# Show the map 
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# Aw, snap! We didn't get a username with your request.
#
# Don't have an account? https://plot.ly/api_signup
#
# Questions? accounts@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-52-1652631f88e6> in <module>
#      42 # Show the map
#      43 fig = dict( data=data, layout=layout )
# ---> 44 py.iplot( fig, filename='d3-cloropleth-map' )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     186         embed_options['height'] = str(embed_options['height']) + 'px'
#     187
# --> 188     return tools.embed(url, **embed_options)
#     189
#     190
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\tools.py in embed(file_owner_or_url, file_id, width, height)
#     399         else:
#     400             url = file_owner_or_url
# --> 401         return PlotlyDisplay(url, width, height)
#     402     else:
#     403         if (get_config_defaults()['plotly_domain']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\tools.py in __init__(self, url, width, height)
#    1479         def __init__(self, url, width, height):
#    1480             self.resource = url
# -> 1481             self.embed_code = get_embed(url, width=width, height=height)
#    1482             super(PlotlyDisplay, self).__init__(data=self.embed_code)
#    1483
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\tools.py in get_embed(file_owner_or_url, file_id, width, height)
#     304                 "'{1}'."
#     305                 "\nRun help on this function for more information."
# --> 306                 "".format(url, plotly_rest_url))
#     307         urlsplit = six.moves.urllib.parse.urlparse(url)
#     308         file_owner = urlsplit.path.split('/')[1].split('~')[1]
#
# PlotlyError: Because you didn't supply a 'file_id' in the call, we're assuming you're trying to snag a figure from a url. You supplied the url, '', we expected it to start with 'https://plot.ly'.
# Run help on this function for more information.
